# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import glob
import torch
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as trns
import torch.nn as nn
from torchmetrics import JaccardIndex
from sklearn.model_selection import train_test_split
from PIL import ImageColor
import matplotlib.patches as mpatches
import torchvision

# %%
class CustomData(Dataset):
    def __init__(self, train=True):
        self.images = []
        self.masks = []
        folders = glob.glob("../data/*")
        for f in folders:
            files = glob.glob(f"{f}/*")
            self.images.append(glob.glob(f"{files[0]}/*")); self.masks.append(glob.glob(f"{files[1]}/*"))
        self.images= np.array(self.images).reshape(-1); self.masks = np.array(self.masks).reshape(-1)
        X_train, X_test, y_train, y_test = train_test_split(self.images, self.masks, test_size=0.2, shuffle=True)
        self.np_images = []
        self.np_masks = []
        trans = trns.Compose([trns.ToTensor(), trns.Resize((256,256))])
        if train:
            for li, lm in zip(X_train, y_train):
                self.np_images.append(trans(plt.imread(li)))
                self.np_masks.append(trans(plt.imread(lm))[:3, :, :])
        else:
            for li, lm in zip(X_test, y_test):
                self.np_images.append(trans(plt.imread(li)))
                self.np_masks.append(trans(plt.imread(lm))[:3, :, :])        
        
    def __getitem__(self, index) :
        return self.np_images[index], self.np_masks[index]
    def __len__(self):
        return len(self.np_images)

# %%
Train_data = CustomData()
Test_data = CustomData(False)
# Out:
# C:\Users\Eslam Yasser\AppData\Roaming\Python\Python311\site-packages\torchvision\transforms\functional.py:153: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:212.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()

# %%
train_loader = DataLoader(Train_data, 1, True)
test_loader= DataLoader(Test_data, 1, shuffle=True)

# %%
x = next(iter(train_loader))

# %%
plt.subplot(1,2,1)
plt.imshow(x[0][0].permute(1,2,0))
plt.subplot(1,2,2)
plt.imshow(x[1][0].permute(1,2,0))

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.double_conv(x)
    
    
class DownBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownBlock, self).__init__()
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)

    def forward(self, x):
        skip_out = self.double_conv(x)
        down_out = self.down_sample(skip_out)
        return (down_out, skip_out)

    
class UpBlock(nn.Module):
    def __init__(self, in_channels, out_channels, up_sample_mode):
        super(UpBlock, self).__init__()
        if up_sample_mode == 'conv_transpose':
            self.up_sample = nn.ConvTranspose2d(in_channels-out_channels, in_channels-out_channels, kernel_size=2, stride=2)        
        elif up_sample_mode == 'bilinear':
            self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            raise ValueError("Unsupported `up_sample_mode` (can take one of `conv_transpose` or `bilinear`)")
        self.double_conv = DoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x)

    
class UNet(nn.Module):
    def __init__(self, out_classes=3, up_sample_mode='conv_transpose'):
        super(UNet, self).__init__()
        self.up_sample_mode = up_sample_mode
        # Downsampling Path
        self.down_conv1 = DownBlock(3, 64)
        self.down_conv2 = DownBlock(64, 128)
        self.down_conv3 = DownBlock(128, 256)
        self.down_conv4 = DownBlock(256, 512)
        # Bottleneck
        self.double_conv = DoubleConv(512, 1024)
        # Upsampling Path
        self.up_conv4 = UpBlock(512 + 1024, 512, self.up_sample_mode)
        self.up_conv3 = UpBlock(256 + 512, 256, self.up_sample_mode)
        self.up_conv2 = UpBlock(128 + 256, 128, self.up_sample_mode)
        self.up_conv1 = UpBlock(128 + 64, 64, self.up_sample_mode)
        # Final Convolution
        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        return x
    

# Get UNet model
model = UNet()

# %%
class diceloss(torch.nn.Module):
    def init(self):
        super(diceloss, self).init()
    def forward(self,pred, target):
       smooth = 1.
       iflat = pred.contiguous().view(-1)
       torchlat = target.contiguous().view(-1)
       intersection = (iflat * torchlat).sum()
       A_sum = torch.sum(iflat * iflat)
       B_sum = torch.sum(torchlat * torchlat)
       return 1 - ((2. * intersection + smooth) / (A_sum + B_sum + smooth) )

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.00008),
])

criterion = diceloss()

# # define learning rate scheduler (not used in this NB)
# lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
#     optimizer, T_0=1, T_mult=2, eta_min=5e-5,
# )

# %%
def Train_model(
        model,
        data_loader,
        criterion,
        optim,
        accuracy,
):
    losses= []
    accS = []
    model.train()
    for img , msk in data_loader:
        img, msk = img.to(DEVICE), msk.to(DEVICE)

        logits = model(img)
        loss = criterion(msk, logits)
        props = nn.functional.softmax(logits, dim=1).cpu()
        acc = accuracy(msk.cpu(), props)
        optim.zero_grad()
        loss.backward()
        optim.step()
        losses.append(loss.detach().cpu()); accS.append(acc.detach().cpu())
    print(f"Train Loss: {np.array(losses).mean() :.4f} | Train Acc: {np.array(accS).mean()*100 :2f}%")
    return np.array(losses).mean(), accS

def Test_model(
        model,
        data_loader,
        criterion,
        accuracy,):
    losses, accS = [], []
    model.eval()
    with torch.inference_mode():
        for img, msk in data_loader:
            img, msk = img.to(DEVICE), msk.to(DEVICE)
            logits = model(img)
            loss = criterion(logits, msk)
            props= nn.functional.softmax(logits, dim=1).cpu()
            acc = accuracy(msk.cpu().detach(), props)
            losses.append(loss.detach().cpu()); accS.append(acc.detach().cpu())
        print(f"Train Loss: {np.array(losses).mean() :.4f}")
        return np.array(losses).mean(), accS

# %%
losses = []
cmS = []
tlosses=[]
tcmS = []

# %%
from torchmetrics import Accuracy

# %%
CM = Accuracy(task="multiclass", num_classes=6)

# %%
model.to(DEVICE)
for i in range(130):
    print(f"{'#'*20} Epoch {i} {'#'*20}")
    print("Training....")
    l, cm = Train_model(model, train_loader, criterion, optimizer, CM)
    losses.append(l); cmS.append(cm)
    print("Testing.......")
    lt, cmt = Test_model(model, test_loader, criterion, CM)
    tlosses.append(lt); tcmS.append(cmt)
# Out:
# #################### Epoch 0 ####################
# Training....
# Train Loss: 0.2857 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0915
# #################### Epoch 1 ####################
# Training....
# Train Loss: 0.0932 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0655
# #################### Epoch 2 ####################
# Training....
# Train Loss: 0.0725 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0538
# #################### Epoch 3 ####################
# Training....
# Train Loss: 0.0670 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0581
# #################### Epoch 4 ####################
# Training....
# Train Loss: 0.0620 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0587
# #################### Epoch 5 ####################
# Training....
# Train Loss: 0.0559 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0526
# #################### Epoch 6 ####################
# Training....
# Train Loss: 0.0518 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0530
# #################### Epoch 7 ####################
# Training....
# Train Loss: 0.0495 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0478
# #################### Epoch 8 ####################
# Training....
# Train Loss: 0.0450 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0487
# #################### Epoch 9 ####################
# Training....
# Train Loss: 0.0449 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0603
# #################### Epoch 10 ####################
# Training....
# Train Loss: 0.0423 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0471
# #################### Epoch 11 ####################
# Training....
# Train Loss: 0.0408 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0492
# #################### Epoch 12 ####################
# Training....
# Train Loss: 0.0396 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0527
# #################### Epoch 13 ####################
# Training....
# Train Loss: 0.0375 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0483
# #################### Epoch 14 ####################
# Training....
# Train Loss: 0.0353 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0457
# #################### Epoch 15 ####################
# Training....
# Train Loss: 0.0342 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0451
# #################### Epoch 16 ####################
# Training....
# Train Loss: 0.0345 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0500
# #################### Epoch 17 ####################
# Training....
# Train Loss: 0.0332 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0493
# #################### Epoch 18 ####################
# Training....
# Train Loss: 0.0314 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0427
# #################### Epoch 19 ####################
# Training....
# Train Loss: 0.0399 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0492
# #################### Epoch 20 ####################
# Training....
# Train Loss: 0.0348 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0451
# #################### Epoch 21 ####################
# Training....
# Train Loss: 0.0310 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0464
# #################### Epoch 22 ####################
# Training....
# Train Loss: 0.0296 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0478
# #################### Epoch 23 ####################
# Training....
# Train Loss: 0.0304 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0441
# #################### Epoch 24 ####################
# Training....
# Train Loss: 0.0294 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0465
# #################### Epoch 25 ####################
# Training....
# Train Loss: 0.0281 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0531
# #################### Epoch 26 ####################
# Training....
# Train Loss: 0.0269 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0454
# #################### Epoch 27 ####################
# Training....
# Train Loss: 0.0266 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0405
# #################### Epoch 28 ####################
# Training....
# Train Loss: 0.0268 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0429
# #################### Epoch 29 ####################
# Training....
# Train Loss: 0.0259 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0413
# #################### Epoch 30 ####################
# Training....
# Train Loss: 0.0247 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0423
# #################### Epoch 31 ####################
# Training....
# Train Loss: 0.0278 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0435
# #################### Epoch 32 ####################
# Training....
# Train Loss: 0.0286 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0494
# #################### Epoch 33 ####################
# Training....
# Train Loss: 0.0242 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0481
# #################### Epoch 34 ####################
# Training....
# Train Loss: 0.0228 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0457
# #################### Epoch 35 ####################
# Training....
# Train Loss: 0.0234 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0544
# #################### Epoch 36 ####################
# Training....
# Train Loss: 0.0223 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0466
# #################### Epoch 37 ####################
# Training....
# Train Loss: 0.0232 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0425
# #################### Epoch 38 ####################
# Training....
# Train Loss: 0.0448 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0529
# #################### Epoch 39 ####################
# Training....
# Train Loss: 0.0326 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0435
# #################### Epoch 40 ####################
# Training....
# Train Loss: 0.0282 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0424
# #################### Epoch 41 ####################
# Training....
# Train Loss: 0.0242 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0464
# #################### Epoch 42 ####################
# Training....
# Train Loss: 0.0222 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0536
# #################### Epoch 43 ####################
# Training....
# Train Loss: 0.0206 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0405
# #################### Epoch 44 ####################
# Training....
# Train Loss: 0.0205 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0495
# #################### Epoch 45 ####################
# Training....
# Train Loss: 0.0200 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0470
# #################### Epoch 46 ####################
# Training....
# Train Loss: 0.0194 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0487
# #################### Epoch 47 ####################
# Training....
# Train Loss: 0.0190 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0600
# #################### Epoch 48 ####################
# Training....
# Train Loss: 0.0185 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0494
# #################### Epoch 49 ####################
# Training....
# Train Loss: 0.0176 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0490
# #################### Epoch 50 ####################
# Training....
# Train Loss: 0.0171 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0476
# #################### Epoch 51 ####################
# Training....
# Train Loss: 0.0167 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0572
# #################### Epoch 52 ####################
# Training....
# Train Loss: 0.0171 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0422
# #################### Epoch 53 ####################
# Training....
# Train Loss: 0.0166 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0552
# #################### Epoch 54 ####################
# Training....
# Train Loss: 0.0166 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0491
# #################### Epoch 55 ####################
# Training....
# Train Loss: 0.0158 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0567
# #################### Epoch 56 ####################
# Training....
# Train Loss: 0.0164 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0517
# #################### Epoch 57 ####################
# Training....
# Train Loss: 0.0153 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0459
# #################### Epoch 58 ####################
# Training....
# Train Loss: 0.0145 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0488
# #################### Epoch 59 ####################
# Training....
# Train Loss: 0.0137 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0497
# #################### Epoch 60 ####################
# Training....
# Train Loss: 0.0133 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0499
# #################### Epoch 61 ####################
# Training....
# Train Loss: 0.0132 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0492
# #################### Epoch 62 ####################
# Training....
# Train Loss: 0.0140 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0528
# #################### Epoch 63 ####################
# Training....
# Train Loss: 0.0239 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0444
# #################### Epoch 64 ####################
# Training....
# Train Loss: 0.0231 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0600
# #################### Epoch 65 ####################
# Training....
# Train Loss: 0.0165 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0586
# #################### Epoch 66 ####################
# Training....
# Train Loss: 0.0140 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0508
# #################### Epoch 67 ####################
# Training....
# Train Loss: 0.0129 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0492
# #################### Epoch 68 ####################
# Training....
# Train Loss: 0.0123 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0533
# #################### Epoch 69 ####################
# Training....
# Train Loss: 0.0123 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0535
# #################### Epoch 70 ####################
# Training....
# Train Loss: 0.0122 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0476
# #################### Epoch 71 ####################
# Training....
# Train Loss: 0.0111 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0473
# #################### Epoch 72 ####################
# Training....
# Train Loss: 0.0110 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0438
# #################### Epoch 73 ####################
# Training....
# Train Loss: 0.0109 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0566
# #################### Epoch 74 ####################
# Training....
# Train Loss: 0.0106 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0517
# #################### Epoch 75 ####################
# Training....
# Train Loss: 0.0102 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0461
# #################### Epoch 76 ####################
# Training....
# Train Loss: 0.0101 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0444
# #################### Epoch 77 ####################
# Training....
# Train Loss: 0.0103 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0534
# #################### Epoch 78 ####################
# Training....
# Train Loss: 0.0100 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0472
# #################### Epoch 79 ####################
# Training....
# Train Loss: 0.0099 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0483
# #################### Epoch 80 ####################
# Training....
# Train Loss: 0.0095 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0509
# #################### Epoch 81 ####################
# Training....
# Train Loss: 0.0097 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0438
# #################### Epoch 82 ####################
# Training....
# Train Loss: 0.0091 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0447
# #################### Epoch 83 ####################
# Training....
# Train Loss: 0.0090 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0554
# #################### Epoch 84 ####################
# Training....
# Train Loss: 0.0096 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0466
# #################### Epoch 85 ####################
# Training....
# Train Loss: 0.0088 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0445
# #################### Epoch 86 ####################
# Training....
# Train Loss: 0.0092 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0467
# #################### Epoch 87 ####################
# Training....
# Train Loss: 0.0088 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0560
# #################### Epoch 88 ####################
# Training....
# Train Loss: 0.0087 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0430
# #################### Epoch 89 ####################
# Training....
# Train Loss: 0.0088 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0573
# #################### Epoch 90 ####################
# Training....
# Train Loss: 0.0095 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0479
# #################### Epoch 91 ####################
# Training....
# Train Loss: 0.0101 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0453
# #################### Epoch 92 ####################
# Training....
# Train Loss: 0.0092 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0450
# #################### Epoch 93 ####################
# Training....
# Train Loss: 0.0081 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0456
# #################### Epoch 94 ####################
# Training....
# Train Loss: 0.0077 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0524
# #################### Epoch 95 ####################
# Training....
# Train Loss: 0.0073 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0463
# #################### Epoch 96 ####################
# Training....
# Train Loss: 0.0074 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0475
# #################### Epoch 97 ####################
# Training....
# Train Loss: 0.0072 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0518
# #################### Epoch 98 ####################
# Training....
# Train Loss: 0.0070 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0545
# #################### Epoch 99 ####################
# Training....
# Train Loss: 0.0066 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0459
# #################### Epoch 100 ####################
# Training....
# Train Loss: 0.0103 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0626
# #################### Epoch 101 ####################
# Training....
# Train Loss: 0.0153 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0442
# #################### Epoch 102 ####################
# Training....
# Train Loss: 0.0107 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0442
# #################### Epoch 103 ####################
# Training....
# Train Loss: 0.0078 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0486
# #################### Epoch 104 ####################
# Training....
# Train Loss: 0.0064 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0520
# #################### Epoch 105 ####################
# Training....
# Train Loss: 0.0060 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0446
# #################### Epoch 106 ####################
# Training....
# Train Loss: 0.0056 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0468
# #################### Epoch 107 ####################
# Training....
# Train Loss: 0.0055 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0491
# #################### Epoch 108 ####################
# Training....
# Train Loss: 0.0058 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0406
# #################### Epoch 109 ####################
# Training....
# Train Loss: 0.0056 | Train Acc: 0.000009%
# Testing.......
# Train Loss: 0.0456
# #################### Epoch 110 ####################
# Training....
# Train Loss: 0.0053 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0407
# #################### Epoch 111 ####################
# Training....
# Train Loss: 0.0053 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0470
# #################### Epoch 112 ####################
# Training....
# Train Loss: 0.0053 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0432
# #################### Epoch 113 ####################
# Training....
# Train Loss: 0.0051 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0407
# #################### Epoch 114 ####################
# Training....
# Train Loss: 0.0052 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0431
# #################### Epoch 115 ####################
# Training....
# Train Loss: 0.0055 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0386
# #################### Epoch 116 ####################
# Training....
# Train Loss: 0.0054 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0512
# #################### Epoch 117 ####################
# Training....
# Train Loss: 0.0051 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0437
# #################### Epoch 118 ####################
# Training....
# Train Loss: 0.0050 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0412
# #################### Epoch 119 ####################
# Training....
# Train Loss: 0.0049 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0553
# #################### Epoch 120 ####################
# Training....
# Train Loss: 0.0049 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0417
# #################### Epoch 121 ####################
# Training....
# Train Loss: 0.0052 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0430
# #################### Epoch 122 ####################
# Training....
# Train Loss: 0.0052 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0427
# #################### Epoch 123 ####################
# Training....
# Train Loss: 0.0054 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0471
# #################### Epoch 124 ####################
# Training....
# Train Loss: 0.0055 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0474
# #################### Epoch 125 ####################
# Training....
# Train Loss: 0.0054 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0414
# #################### Epoch 126 ####################
# Training....
# Train Loss: 0.0051 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0479
# #################### Epoch 127 ####################
# Training....
# Train Loss: 0.0061 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0461
# #################### Epoch 128 ####################
# Training....
# Train Loss: 0.0056 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0470
# #################### Epoch 129 ####################
# Training....
# Train Loss: 0.0059 | Train Acc: 0.000000%
# Testing.......
# Train Loss: 0.0477

# %%
plt.figure(figsize=(15,6))
plt.plot(losses, label="train")
plt.plot(tlosses, label="test")
plt.legend()

# %%
d = iter(test_loader)

# %%
x = next(d)

# %%
model.eval()
with torch.no_grad():
    pred = model(x[0][0].unsqueeze(0).to(DEVICE))

plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
plt.imshow(x[0].squeeze().permute(1,2,0))
plt.subplot(1,3,2)
plt.imshow(x[1].squeeze().permute(1,2,0))
plt.subplot(1,3,3)
plt.imshow(pred.squeeze().permute(1,2,0).cpu())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import umetrix

# %%
result = umetrix.calculate(
    x[0].squeeze().permute(1,2,0).numpy(),
    x[0].squeeze().permute(1,2,0).numpy(),
    strict=True,
    iou_threshold=0.7
)

# %%
result.results
# Out:
# ============================
#  Segmentation Metrics (n=1)
# ============================
# Strict: True (IoU > 0.7)
# n_true_labels: 1
# n_pred_labels: 1
# n_true_positives: 1
# n_false_positives: 0
# n_false_negatives: 0
# IoU: 1.000
# Jaccard: 1.000
# pixel_identity: 1.000
# localization_error: 0.000

# %% [markdown]
# # segementation metrics
#
# #### Accuracy, Validation Accuracy, Loss, Validation Loss, IoU, Validation IoU

# %% [markdown]
# # hypred model

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
plt.imshow(x[0].squeeze().permute(1,2,0))

plt.subplot(1,3,2)
plt.imshow(x[1].squeeze().permute(1,2,0))

plt.subplot(1,3,3)
plt.imshow(pred.cpu().squeeze().permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
